# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from modules.lane_detection import *

# %%
image = cv.imread("Data\Images\Straight Lines 1.jpg")
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))

# %%
h, s, v = cv.split(image)
white_s_thresholded = cv.threshold(s, 30, 255, cv.THRESH_BINARY_INV)
white_v_thresholded = cv.threshold(v, 100, 255, cv.THRESH_BINARY)
yellow_h_thresholded = cv.bitwise_and(cv.threshold(h, 80, 255, cv.THRESH_BINARY), cv.threshold(h, 120, 255, cv.THRESH_BINARY_INV))
yellow_s_thresholded = cv.threshold(s, 140, 255, cv.THRESH_BINARY)
yellow_v_thresholded = cv.threshold(s, 100, 255, cv.THRESH_BINARY)
white_mask = cv.bitwise_and(white_s_thresholded, white_v_thresholded)
yellow_mask = cv.bitwise_and(cv.bitwise_and(yellow_h_thresholded, yellow_s_thresholded), yellow_v_thresholded)
lanes = cv.bitwise_or(white_mask, yellow_mask)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-bf0efd72dd4a> in <module>
#       5 yellow_s_thresholded = cv.threshold(s, 140, 255, cv.THRESH_BINARY)
#       6 yellow_v_thresholded = cv.threshold(s, 100, 255, cv.THRESH_BINARY)
# ----> 7 white_mask = cv.bitwise_and(white_s_thresholded, white_v_thresholded)
#       8 yellow_mask = cv.bitwise_and(cv.bitwise_and(yellow_h_thresholded, yellow_s_thresholded), yellow_v_thresholded)
#       9 lanes = cv.bitwise_or(white_mask, yellow_mask)
#
# error: OpenCV(4.5.5) :-1: error: (-5:Bad argument) in function 'bitwise_and'
# > Overload resolution failed:
# >  - src1 is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'src1'

# %%
plt.imshow(detect_lanes(image), cmap = "gray")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-34ad7e3cb4ea> in <module>
# ----> 1 plt.imshow(detect_lanes(image), cmap = "gray")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...
