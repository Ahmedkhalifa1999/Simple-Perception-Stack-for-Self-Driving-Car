# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
image = cv.imread("Data/Images/Straight Lines 1.jpg")

# %%
def show_image(image):
    plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))

# %%
video = cv.VideoCapture("Data/Main Video.mp4")

# %%
show_image(image)

# %%
b, g, r = cv.split(image)

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
b.dtype
# Out:
# dtype('uint8')

# %%
b = cv.add(b, np.full((image.shape[0], image.shape[1]), 255, dtype=b.dtype))

# %%
masked = cv.merge((b, g, r))

# %%
show_image(masked)

# %%
video.release()
